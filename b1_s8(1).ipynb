# %%
#The movie was not good


#Token1- The
#Memory- sentence started

#Token2- Movie
#Memory- subject is movie

#token3- was
#memory- waiting for description

#token4- not
#memory- negation active

#token5- good
#memory- good appeares but not changes the meaning

# %%
#Hidden memory-

#sentiment analysis
#language translations

# %%
sentence = "the movie was not good"
tokens= sentence.split()

memory =""

for token in tokens:
    memory = memory + token + " "
    print("Current token:", token)
    print("Memory so far:", memory.strip())
    print("----------------")
# Out:
# Current token: the
# Memory so far: the
# ----------------
# Current token: movie
# Memory so far: the movie
# ----------------
# Current token: was
# Memory so far: the movie was
# ----------------
# Current token: not
# Memory so far: the movie was not
# ----------------
# Current token: good
# Memory so far: the movie was not good
# ----------------

# %%
sentence = "the movie was not good"
tokens = sentence.split()

hidden_state = {
    "topic": None,
    "negation_active": False,
    "sentiment_word": None
}

for token in tokens:
    if token in ["movie", "food", "product"]:
        hidden_state["topic"] = token

    if token == "not":
        hidden_state["negation_active"] = True

    if token in ["good", "bad", "great", "terrible"]:
        hidden_state["sentiment_word"] = token

    print("Token:", token)
    print("Hidden state:", hidden_state)
    print("-----")
# Out:
# Token: the
# Hidden state: {'topic': None, 'negation_active': False, 'sentiment_word': None}
# -----
# Token: movie
# Hidden state: {'topic': 'movie', 'negation_active': False, 'sentiment_word': None}
# -----
# Token: was
# Hidden state: {'topic': 'movie', 'negation_active': False, 'sentiment_word': None}
# -----
# Token: not
# Hidden state: {'topic': 'movie', 'negation_active': True, 'sentiment_word': None}
# -----
# Token: good
# Hidden state: {'topic': 'movie', 'negation_active': True, 'sentiment_word': 'good'}
# -----

# %%
import tensorflow as tf
from tensorflow.keras import layers

#the movie was not good
vocab_size = 1000 #1000 most common words for the model to consider
embedding_dim = 16 #size of the word vectors
sequence_length = 8

simple_rnn_model = tf.keras.Sequential([ #
    layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=sequence_length), #
    layers.SimpleRNN(32), #neural network layer of 32 nodes
    layers.Dense(1, activation="sigmoid") #0 or 1
])

simple_rnn_model.summary()

#create a proper tokensiation system that takes in sentences ( keep 3 sentences) vectorises thise sentences, converts to embeddings and once done shows sentiment
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#create a proper tokensiation system that takes in sentences ( keep 3 sentences) vectorises thise sentences, converts to embeddings and once done shows sentiment

# %%
# I grew up in France. I moved to India for college. I studied engineering. I speak fluent FRENCH
#LONG SHORT TERM MEMORY

# %%
#CELL STATE

#Hidden state

#forget gate-- decides what to forget or what info to delete
#points to input gate and deletes the irrelevant info

#input gate;
